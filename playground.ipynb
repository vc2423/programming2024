# %%
import pandas as pd

# %%
import numpy as np

# %%
1 == 2
# Out:
# False

# %%
df = pd.read_csv("student_lifestyle_dataset.csv")

# %%
df
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0              1                  6.9                            3.8
# 1              2                  5.3                            3.5
# 2              3                  5.1                            3.9
# 3              4                  6.5                            2.1
# 4              5                  8.1                            0.6
# ...          ...                  ...                            ...
# 1995        1996                  6.5                            0.2
# 1996        1997                  6.3                            2.8
# 1997        1998                  6.2                            0.0
# 1998        1999                  8.1                            0.7
# 1999        2000                  9.0                            1.7
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 0                     8.7                   2.8
# ...

# %%
import sqlite3

# %%
# !pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
ev = pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
ev
# Out:
#         VIN (1-10)    County            City State  Postal Code  Model Year  \
# 0       1N4AZ0CP8D      King       Shoreline    WA      98177.0        2013
# 1       5YJSA1E45K      King         Seattle    WA      98112.0        2019
# 2       WVGUNPE28M    Kitsap          Olalla    WA      98359.0        2021
# 3       JTDKARFP6H  Thurston         Olympia    WA      98501.0        2017
# 4       1FADP5CU9G  Thurston         Olympia    WA      98506.0        2016
# ...            ...       ...             ...   ...          ...         ...
# 216767  1G1RB6E44D   Douglas  East Wenatchee    WA      98802.0        2013
# 216768  KNDCS3LF9R   Whatcom      Bellingham    WA      98229.0        2024
# 216769  7SAYGAEE9R      King         Redmond    WA      98052.0        2024
# 216770  1G1RB6E49D    Pierce      Gig Harbor    WA      98329.0        2013
# 216771  5YJ3E1EA1P    Pierce     Bonney Lake    WA      98391.0        2023
#
# ...

# %%
evny = pd.read_csv("NYC_EV_Fleet_Station_Network.csv")

# %%
evny
# Out:
#         AGENCY                    STATION NAME                TYPE OF CHARGER  \
# 0          ACS     NYC FLEET / ACS_LINDEN_1_L3           Level 3 Fast Charger
# 1          ACS     NYC FLEET / ACS_LINDEN_2_L3           Level 3 Fast Charger
# 2          ACS        NYC FLEET / ACS_LINDEN-1                Level 2 Charger
# 3          ACS       NYC FLEET / ACSSTMARKSPL1                Level 2 Charger
# 4     CITYHALL       NYC FLEET / CITYHALL EAST                Level 2 Charger
# ...        ...                             ...                            ...
# 1405       DOT  DOT LOT QUEENS BOROUGH HALL L2  DOT Municipal Level 2 Charger
# 1406       DOT  DOT LOT QUEENS BOROUGH HALL L3  DOT Municipal Level 3 Charger
# 1407       DOT     DOT LOT QUEENS FAMILY COURT  DOT Municipal Level 2 Charger
# 1408       DOT   DOT LOT QUEENSBORO HALL FIELD  DOT Municipal Level 2 Charger
# 1409       DOT               DOT LOT ST GEORGE  DOT Municipal Level 2 Charger
#
# ...

# %%
print(evny.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1410 entries, 0 to 1409
# Data columns (total 18 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   AGENCY                                     1410 non-null   object
#  1   STATION NAME                               1410 non-null   object
#  2   TYPE OF CHARGER                            1410 non-null   object
#  3   NO. OF PLUGS                               1410 non-null   int64
#  4   ADDRESS                                    1399 non-null   object
#  5   CITY                                       1399 non-null   object
#  6   POSTCODE                                   1399 non-null   float64
#  7   BOROUGH                                    1399 non-null   object
#  8   PUBLIC CHARGER?                            73 non-null     object
#  9   FEE FOR CITY DRIVERS                       71 non-null     object
# ...

# %%
evny.dropna(subset=["POSTCODE"], inplace=True)

# %%
evny["POSTCODE"] = evny["POSTCODE"].astype(int)

# %%
print(evny.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1399 entries, 0 to 1409
# Data columns (total 18 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   AGENCY                                     1399 non-null   object
#  1   STATION NAME                               1399 non-null   object
#  2   TYPE OF CHARGER                            1399 non-null   object
#  3   NO. OF PLUGS                               1399 non-null   int64
#  4   ADDRESS                                    1399 non-null   object
#  5   CITY                                       1399 non-null   object
#  6   POSTCODE                                   1399 non-null   int64
#  7   BOROUGH                                    1399 non-null   object
#  8   PUBLIC CHARGER?                            73 non-null     object
#  9   FEE FOR CITY DRIVERS                       71 non-null     object
# ...

# %%
zipcode = pd.read_csv("uszips.csv")

# %%
zipcode
# Out:
#          zip       lat        lng         city state_id   state_name  zcta  \
# 0        601  18.18027  -66.75266     Adjuntas       PR  Puerto Rico  True
# 1        602  18.36075  -67.17541       Aguada       PR  Puerto Rico  True
# 2        603  18.45744  -67.12225    Aguadilla       PR  Puerto Rico  True
# 3        606  18.16585  -66.93716      Maricao       PR  Puerto Rico  True
# 4        610  18.29110  -67.12243       Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...          ...      ...          ...   ...
# 33779  99923  55.98043 -130.03803        Hyder       AK       Alaska  True
# 33780  99925  55.55398 -132.96276      Klawock       AK       Alaska  True
# 33781  99926  55.12617 -131.48928   Metlakatla       AK       Alaska  True
# 33782  99927  56.33305 -133.60044  Point Baker       AK       Alaska  True
# 33783  99929  56.36089 -132.00635     Wrangell       AK       Alaska  True
#
# ...

# %%
print(zipcode.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33784 entries, 0 to 33783
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   zip               33784 non-null  int64
#  1   lat               33784 non-null  float64
#  2   lng               33784 non-null  float64
#  3   city              33784 non-null  object
#  4   state_id          33784 non-null  object
#  5   state_name        33784 non-null  object
#  6   zcta              33784 non-null  bool
#  7   parent_zcta       0 non-null      float64
#  8   population        33767 non-null  float64
#  9   density           33767 non-null  float64
#  10  county_fips       33784 non-null  int64
#  11  county_name       33784 non-null  object
#  12  county_weights    33784 non-null  object
#  13  county_names_all  33784 non-null  object
#  14  county_fips_all   33784 non-null  object
#  15  imprecise         33784 non-null  bool
# ...

# %%
zipcode_ny = zipcode.loc[(zipcode['zip'] >= 10001) & (zipcode['zip'] <= 11256)]

# %%
zipcode_ny
# Out:
#         zip       lat       lng      city state_id state_name  zcta  \
# 2582  10001  40.75064 -73.99728  New York       NY   New York  True
# 2583  10002  40.71597 -73.98692  New York       NY   New York  True
# 2584  10003  40.73184 -73.98915  New York       NY   New York  True
# 2585  10004  40.69431 -74.01835  New York       NY   New York  True
# 2586  10005  40.70614 -74.00862  New York       NY   New York  True
# ...     ...       ...       ...       ...      ...        ...   ...
# 2884  11236  40.63951 -73.90098  Brooklyn       NY   New York  True
# 2885  11237  40.70427 -73.92108  Brooklyn       NY   New York  True
# 2886  11238  40.67105 -73.96636  Brooklyn       NY   New York  True
# 2887  11239  40.64733 -73.87136  Brooklyn       NY   New York  True
# 2888  11249  40.71121 -73.96318  Brooklyn       NY   New York  True
#
#       parent_zcta  population  density  county_fips county_name  \
# 2582          NaN     27004.0  16713.6        36061    New York
# ...
